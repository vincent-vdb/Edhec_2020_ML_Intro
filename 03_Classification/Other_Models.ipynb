# %% [markdown]
# - Many more models of classification
# - k-NN
# - Naive Bayes
# - Perceptron
# - ...

# %% [markdown]
# # IV. Other popular classification models

# %% [markdown]
# ## III.1. Naive Bayes

# %% [markdown]
# **Naive Bayes classifiers** are a family of simple "probabilistic classifiers" based on **Bayes' theorem**.
#
# It implies a strong (this is why this algorithm is considered *naive*) **independence assumptions between the features**.
#
# > 📚 **Resources**: Read more on [Naive Bayes algorithms](https://en.wikipedia.org/wiki/Naive_Bayes_classifier) and on [Naive Bayes spam filtering](https://en.wikipedia.org/wiki/Naive_Bayes_spam_filtering) 📩
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1JVzJXqW-n5zaSAB1HWpF_JLCDfNWVFx0">
# </p>

# %% [markdown]
# Let's take an example:
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1_sqdZEhlrpc771fKtr6mScj36awedn1x">
# </p>

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=19pTAAg6wMxQnwzWtRl8uB4GBOtbdJcKb">
# </p>

# %%
# scikit-learn implementation
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X, y)
y_pred = gnb.predict(X)
acc = accuracy_score(y, y_pred)
print("Naive Bayes model has an accuracy of {}%".format(round(acc*100), 2))
# Out:
# Naive Bayes model has an accuracy of 78.0%

# %% [markdown]
# ### Example of decision boundaries
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1kFkjsi9XNmt4vSkfALB1aFWKjcXy0OYS" width="350">
# </p>

# %% [markdown]
# ## III.2. Support Vector Machines

# %% [markdown]
# **SVM** are quite recent, as the original algorithm was invented in 1963.
#
# A **support-vector machine** constructs what is called a **hyperplane** (a separation - such a line in 2D space, or a surface plane in 3D) to separate classes.
#
# There might be many hyperplanes that might classify the data. One reasonable choice as the best separation is the one that has **the largest distance to the nearest training-data point of any class** (we call this distance the **margin**).
#
# > 📚 **Resources**: Read more on [Support Vector Machines](https://en.wikipedia.org/wiki/Support-vector_machine)

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=14Wc6tcVMbCwT_0ne4jSH6pjhL0CVly-B" width="350">
# </p>
#
# - H1 does not separate the classes at all
# - H2 does, but only with a small margin
# - H3 separates them with the maximal margin

# %%
# scikit-learn implementation
from sklearn.svm import SVC
svc = SVC(kernel='linear')
svc.fit(X, y)
y_pred = svc.predict(X)
acc = accuracy_score(y, y_pred)
print("SVM model has an accuracy of {}%".format(round(acc*100), 2))
# Out:
# SVM model has an accuracy of 82.0%

# %% [markdown]
# ### The Kernel Trick
#
# In addition to performing **linear classification** (separating classes with a line), SVMs can efficiently perform a **non-linear classification** using what is called the **kernel trick**, by replacing the usual dot product (for computing the distances) by a non linear function.
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1UTyeUCAGFgU_NbiFE5xqmqRuKm2BpNM5" width="400">
# </p>

# %%
# scikit-learn implementation

svc_k = SVC(kernel="rbf")
svc_k.fit(X, y)
y_pred_k = svc_k.predict(X)
acc_k = accuracy_score(y, y_pred_k)
print("SVM model (with the kernel trick) has an accuracy of {}%".format(round(acc_k*100), 2))
# Out:
# SVM model (with the kernel trick) has an accuracy of 83.0%

# %%
# Create figure to draw chart
plt.figure(figsize=(20, 8))

# We create a grid of points contained within [x_min, x_max]x[y_min, y_max] with step h=0.02
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
h = .02  # step size of the grid
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# Retrieve predictions for each point of the grid
Z_svc = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z_svc = Z_svc.reshape(xx.shape)

Z_svc_k = svc_k.predict(np.c_[xx.ravel(), yy.ravel()])
Z_svc_k = Z_svc_k.reshape(xx.shape)

plt.subplot(1, 2, 1)
# Plot the decision boundary (label predicted assigned to a color)
plt.pcolormesh(xx, yy, Z_svc, cmap=plt.cm.Paired)

# And plot the testing point in white
plt.scatter(X[:, 0], X[:, 1], c=y,
            edgecolors='k',cmap=plt.cm.Paired, alpha=0.8, s=40)

# Format chart
plt.title(f"Decision boundaries with SVM (no kernel trick)\nAccuracy: {round(acc*100)} %")
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xticks(())
plt.yticks(())


plt.subplot(1, 2, 2)
# Plot the decision boundary (label predicted assigned to a color)
plt.pcolormesh(xx, yy, Z_svc_k, cmap=plt.cm.Paired)

# And plot the testing point in white
plt.scatter(X[:, 0], X[:, 1], c=y,
            edgecolors='k',cmap=plt.cm.Paired, alpha=0.8, s=40)

# Format chart
plt.title(f"Decision boundaries with SVM (with kernel trick)\nAccuracy: {round(acc_k*100)} %")
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xticks(())
plt.yticks(())

plt.show()

# %% [markdown]
# ### Examples of decision boundaries
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1zIvg6xR4PPCvegzTbfyvLvcahs16mGvI" width="400">
# </p>

# %% [markdown]
# ## III.3. Trees and forests 🌳🌳🌳

# %% [markdown]
# We will talk about this category of models later 🙂

# %% [markdown]
# ## IV.1. KNearest Neighbors Regressor

# %% [markdown]
# ### IV.1.A. Intuition

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1AAb0Q0pmB2lCkS5ToMAdjI5naxGFrX_Q">
# </p>

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=10gkXUJ25UF-ljWSOrWncNBQyAtHiwE3x">
# </p>

# %% [markdown]
# We compute the distance of the point ID 11 with all the other points.
# For instance, the distance with the point ID 10 is:
#
# $$\displaystyle distance=\sqrt{(5.5-5.6)^2 + (38-32)^2}$$

# %% [markdown]
# For instance, if you choose k = 3, you choose the 3 closest points (ID 6, 5 and 1 as shown in the graph) and the value of the weight value for ID 11 is the average of the weight value of these three points:
#
# $$\displaystyle Weight_{ID_{11}}=\frac{(60+72+77)}{3} $$

# %% [markdown]
# ### IV.1.B. Implementation with Scikit learn

# %%
from sklearn.neighbors import KNeighborsRegressor

# Create k neighbors regressor object
Knr = KNeighborsRegressor(n_neighbors=3)

# %%
# Train the model using only the first feature of X (Surface)
Knr.fit(X, y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform')

# %%
# Make predictions based on train model
y_pred = Knr.predict(np.sort(X, axis=0))

# %%
# Create figure to draw chart
plt.figure(2, figsize=(10, 8))

# Plot the training points
plt.scatter(X[:, 0], y)
plt.plot(np.sort(X[:, 0], axis=0), y_pred, color='red', linewidth=3)

plt.xlabel('Average Number of Rooms')
plt.ylabel('Price')

plt.show()

# %%
#We check the mean squared error to compare it with other models
mse = mean_squared_error(y_pred, y)
print(mse)
# Out:
# 182.91273166447078

# %% [markdown]
# ⚠️ As you might have noticed, we have **sorted** the values in X before making a prediction.
#
# If we hadn't sorted them, the resulting plot would look like that :

# %%
# Make a prediction WITHOUT sorting the values in `X`
y_pred = Knr.predict(X)

# %%
# Create figure to draw chart
plt.figure(2, figsize=(6, 4))

# Plot the training points
plt.scatter(X[:, 0], y)
plt.plot(X[:, 0], y_pred, color='red', linewidth=3)

plt.xlabel('Average Number of Rooms')
plt.ylabel('Price')

plt.show()

# %% [markdown]
# Not very readable, is it ?
#
# The issue in the above graph shows that the algorithm starts with the first point in the dataset, then the second, then the third... These points are not necessarily the ones with the smallest values (representing an Average Number of Rooms around 4 in the graph above).
#
# ➡️ To solve this graphic issue, it is better to sort the points in the dataset to predict and to graph.

# %% [markdown]
# ## IV.2. Support Vector Machine Regressor

# %% [markdown]
# ### IV.2.A. Intuition

# %% [markdown]
# As for classification, **SVM** is also available with linear and non linear kernel when it comes to regression/

# %% [markdown]
# The target of the algorithm is to find a line or a curve (depending on the used kernel) :
# - that **contains the maximum number of points within a margin interval**: \[-ε, ε\] in the graph below
# - and that **minimizes the error**.
#
# **The error**, ζ in the graph, is the sum of the distances of the points that are outside the margin interval, to the closest margin line.

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1bw8W4TXHf64C3rQ_6D0uxFH7ctXAF3qX">
# </p>

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1Ww7pwEcya6xUEsD7UyUXx76KexKwElrb">
# </p>

# %% [markdown]
# ➡️ While the support vector machine for classification tries to maximise the margin between two classes, the regressor tries to input the errors inside this margin (the bigger the margins are, the less the model is impacted by errors).

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1ZSSmAYrz6Jpsjhvj70HnDrN1E3ScoMWU">
# </p>

# %% [markdown]
# > 📚 **Resources** : if you are interested in mathematics, check out [Understanding Support Vector Machine Regression](https://www.mathworks.com/help/stats/understanding-support-vector-machine-regression.html)

# %% [markdown]
# ### IV.2.B. Implementation with Scikit learn

# %%
from sklearn.svm import SVR

# Create a support vector machine for regression with a linear kernel
svr_linear = SVR(kernel="linear")

# %%
# Train the model using only the first feature of X (Surface)
svr_linear.fit(X, y)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='linear', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# Make predictions based on train model
y_pred = svr_linear.predict(X)

# %%
# Create figure to draw chart
plt.figure(2, figsize=(10, 8))

# Plot the training points
plt.scatter(X[:, 0], y)
plt.plot(X[:, 0], y_pred, color='red', linewidth=3)

plt.xlabel('Average Number of Rooms')
plt.ylabel('Price')

plt.show()

# %%
#We check the mean squared error to compare it with other models
mse = mean_squared_error(y, y_pred)
print(mse)
# Out:
# 43.65312950467825

# %%
from sklearn.svm import SVR

# Create a support vector machine for regression with a non linear kernel (rbf in this example)
svr_rbf = SVR(kernel = "rbf")

# %%
# Train the model using only the first feature of X (Surface)
svr_rbf.fit(X, y)
# Out:
# /Users/Clement/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# Make predictions based on train model (as for knn, X must be sorted tobe graphed properly)
y_pred = svr_rbf.predict(np.sort(X, axis = 0))

# %%
# Create figure to draw chart
plt.figure(2, figsize=(10, 8))

# Plot the training points
plt.scatter(X[:, 0], y)
plt.plot(np.sort(X[:, 0], axis = 0), y_pred, color='red', linewidth=3)

plt.xlabel('Average Number of Rooms')
plt.ylabel('Price')

plt.show()

# %%
#We check the mean squared error to compare it with other models
mse = mean_squared_error(y, y_pred)
print(mse)
# Out:
# 154.75131428636857

# %% [markdown]
# ## IV.3. RANSAC: Random Sample Consensus

# %% [markdown]
# ### IV.3.A Intuition

# %%
# Create figure to draw chart
plt.figure(2, figsize=(10, 8))

# Plot the training points
col = np.where((y <15) & (X[:, 0] > 6) & (X[:, 0] <7), 'g',np.where((y == 50) & (X[:, 0] < 7.5),'r', 'b'))
plt.scatter(X[:, 0], y, c = col)
plt.plot(X, lr.predict(X), c = 'r')
plt.show()

# %% [markdown]
# The points in red or in green have an important impact on the slope of the regression line.
#
# ➡️ Are they **inliners** or **outliers** ?

# %% [markdown]
# With a more obvious example:

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1IQqYc8i0kGzAK-Gv2fKATK1-3IObEHRX">
# </p>

# %% [markdown]
# The points in yellow in the graph above can be points that you don't want to take into account in your regression :  they could for instance represent **measures by a machine that makes error because of malfunctions** ; e.g., they could be **outliers**.
#
# ➡️ **RANSAC** allows you to remove those points and make a regression using the steps described below.

# %% [markdown]
# RANSAC is an **iterative algorithm**. At each iteration it performs the following steps:
#
# 1️⃣ Select randomly a sub sample and fit a model on this data.
#
# 2️⃣ Check the other points with this model: if a point is correctly estimated, it is considered as an inlier, if not, as an outlier.
#
# 3️⃣ The model is trained again but only with the "as inlier" estimated points and its score is measured.
#
# 4️⃣ Next iteration, another model is fitted with another sub sample, if it has at least the same number of inliers as described in the previous step 2, it is tested as explained in the step 3. If its score is better than previous model, it becomes the better one...

# %% [markdown]
# ### IV.3.B Implementation with scikit learn

# %%
from sklearn.linear_model import RANSACRegressor

# Create a RANSAC object
ransac = RANSACRegressor()

# %%
# Train the model using only the first feature of X (Surface)
ransac.fit(X, y)
# Out:
# RANSACRegressor(base_estimator=None, is_data_valid=None, is_model_valid=None,
#                 loss='absolute_loss', max_skips=inf, max_trials=100,
#                 min_samples=None, random_state=None, residual_threshold=None,
#                 stop_n_inliers=inf, stop_probability=0.99, stop_score=inf)

# %%
# Make predictions based on train model
y_pred = ransac.predict(X)

# %%
# Create figure to draw chart
plt.figure(2, figsize=(10, 8))

# Plot the training points
plt.scatter(X[:, 0], y, c = ransac.inlier_mask_)
plt.plot(X[:, 0], y_pred, color='red', linewidth=3, label = 'RANSAC')
plt.plot(X[:, 0], lr.predict(X), color = 'green', linewidth = 3, label = 'linear regression')
plt.xlabel('Average Number of Rooms')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
#We check the mean squared error to compare it with other models
mse = mean_squared_error(y,y_pred)
print(mse)
# Out:
# 44.60668331936277

# %% [markdown]
# The results are worse than with a linear regression, since the model is trained only on inliers (points in yellow) and its errors calculated on all the points (yellow and purple) in the dataset.
