# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ---

# %% [markdown]
# In this course, we will talk about the importance of **properly visualizing your data** and we will explore different **visualization tools** and **charts** that you can use.
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1Uyu2HQGTNbeZ-BLesnWGb7n406D9Xx-d" width="600px">
# </p>

# %% [markdown]
# ---

# %% [markdown]
# # I. Introduction to data visualization

# %% [markdown]
# ## I.1. Bad dataviz is wrong

# %% [markdown]
# > 🏆 **Quiz**: What is wrong with this chart?
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=10e0FthDexZJrwqQMoZ6yxIr6dYTVHpDE" width="500px">
# </p>

# %% [markdown]
# > ✅ **Answer**:
# >
# > Axis should start at 0. Let's represent this graphic properly.

# %%
from matplotlib import pyplot as plt

plt.figure()

plt.bar(["Now", "1th Jan 2013"],
        [35, 39.5])

plt.show()

# %% [markdown]
# > 🏆 **Quizz**: iPhones sales are booming! Can't you see? Wait..what?
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1jXrbJJaHc1q1hatGOtFa5nVCg7Bzd_Au" width="60%">
# </p>

# %% [markdown]
# > ✅ **Answer**:
# >
# > Cumulative is misleading (always growing). We call it a **bullshit metric** 🙊
# >
# > Plus, Y-axis is missing!
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1XAWKarXC44gnWIKCciwYJffLfikRoz12" width="60%">
# </p>

# %% [markdown]
# > 🏆 **Quizz**: What is wrong with this chart?
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1_FwAOB0iWSa4mi-E02xdzRvlr-mB7tXD" width="80%">
# </p>

# %% [markdown]
# > ✅ **Answer**:
# >
# > Difference of Y-axis scales - **WRONG!**

# %% [markdown]
# > 🏆 **Quizz**: Global warming does not exist! This graph proves it. Do you agree?
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1vAEMPUCga0oEc7yjJBIzy8QNYDnZz7cW" width="60%">
# </p>

# %% [markdown]
# > ✅ **Answer**:
# >
# > Zoom out...
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1FDNf-9jor4262EsvcxBax78WhokRIgw0" width="60%">
# </p>

# %% [markdown]
# > ✅ **Answer**:
# >
# > Global warming is supposed to happen over a large period of time. Zoom out again!
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1G8izBZSkJNwZtUrnTLPpqkA6i7Q5toVg" width="60%">
# </p>

# %% [markdown]
# > 🏆 **Quizz**: What is wrong with this chart?
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1g2q2ZNqTbX9HwEn944-PsmbWXCumEw43" width="600">
# </p>

# %% [markdown]
# > ✅ **Answer**:
# >
# > `Apple` (19.5%) looks bigger than `Other` (21.2%) 🤔
# >
# > **NO pie-chart**: comparing angle is hard.
# >
# > On top of that, **NO 3D volume neither!**: it falses data-ink ratio (we will see more about that).
# >
# > Bad Steve, bad.. Let's redo this graph the proper way.

# %%
plt.figure(figsize=(10,6), dpi=100)

plt.bar(["RIM", "Other", "Apple", "Palm", "Motorola", "Nokia"],
        [39.0, 21.2, 19.5, 9.8, 7.4, 3.1])
plt.title("U.S. SmartPhone Marketshare", fontweight="bold")

plt.show()

# %% [markdown]
# ## I.2. Good dataviz is _key_ and _impactful_

# %% [markdown]
# ### I.2.A. The 7 bridges of Königsberg

# %% [markdown]
# There is a very famous puzzle called the **[7 bridges of Königsberg](https://en.wikipedia.org/wiki/Seven_Bridges_of_Königsberg)**. The goal is the following:
#
# > 🏆 **Quizz**: Find a walk through the city that crosses each of those bridges once and only once.
# >
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1Gyco_DHUkTlLuZlSlO5v8QzXzA1CZo0z" width="350">
# </p>

# %% [markdown]
# If you represent the problem correctly, it becomes really easy to solve it with graph theory (counting number of nodes, degrees of the node, etc.).
#
# The history was the other way around though, Euler used this problem and the new graph representation to **laid the foundations of graph theory**.
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=14e-99rWQrPs2UOPkxc_QWqCcE8cZ_Cq9" width="600">
# </p>

# %% [markdown]
# ### I.2.B. The Napoleon's Russian campain of 1812

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1z6CCvSYaAbRR4M72FjApjv7RskTyAO1c" width="1000">
# </p>

# %% [markdown]
# ### I.2.C. Other various dataviz

# %% [markdown]
# **Example**: [@instachaaz](http://www.instagram.com/instachaaz)
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1ghg3fov3zm2iv5yxMCReq9IXS6jY38qE" width="50%">
# </p>

# %% [markdown]
# **Example**: New York Times - ex: "First Leaf" Appearence 🍀
#
# <img src="https://drive.google.com/uc?export=view&id=1yuwll9vZXzoz4HCURPvSaepios4qgf3E">

# %% [markdown]
# Other cool examples of dataviz:
# - Gender discrimination in Disney movies: https://pudding.cool/2017/03/film-dialogue/
# - New York Times best data visualizations - https://www.informationisbeautifulawards.com/news/118-the-nyt-s-best-data-visualizations-of-the-year
# - Inspiration for great presentations: http://emiland.me/

# %% [markdown]
# ---

# %% [markdown]
# # II. Build great visualizations

# %% [markdown]
# ## II.1. Choose _carefully_ your chart - what is your message?

# %% [markdown]
# Data visualization is all about **storytelling**: what message do you want to convey?
#
# An histogram will highlight something different than a scatter plot, that will tell a different story than a line chart, etc.
#
# Start by answering some questions about your data and the goal of your visualization:
# - Are you trying to answer a question (ex: are the iPhone sales growing over time - at what pace)? To confirm/infirm an hypothesis (ex: is global warming real)? To convey a message (ex: should you buy Bitcoin **now**)?
# - What would be the best chart(s) to do so?
# - What data do you need to draw this/these chart(s)?
# - Collect this data (you know how to do that now), aggregate it
# - Draw your chart(s)! 🎨

# %% [markdown]
# A good framework to determine which chart to choose:
#
# <img src="https://drive.google.com/uc?export=view&id=1DqlfAhIn7k7AG5ogQIxFsZ7YZeBJLgWv" width="800">

# %% [markdown]
# Similarly, you can answer the questions above interactively here: http://whichgraph.com/

# %% [markdown]
# ## II.2. Maximize the data-ink ratio

# %% [markdown]
# The **Data-Ink ratio** is a concept introduced by Edward Tufte, the expert whose work has contributed significantly to designing effective data visualizations.
#
# In his 1983 book, *The Visual Display of Quantitative Data*, he stated the goal:
# > Above all else, show the data.
# >
# > *Tufte, 1983*
#
# He then defined the **data-ink ratio** as **the proportion of ink** (or pixels) **that is used to present actual data compared to the total amount of ink** (or pixels) **used in the entire display**.
#
# $$Data \: Ink \: Ratio = \frac{Data \: Ink}{Total \: ink \: used \: in \: graphic}$$
#
# In other words, focus on showing the data and remove everything irrelevant.
#
# As we say: **LESS IS MORE**.

# %% [markdown]
# This does not respect the **Max Data-Ink Ratio** rule:
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1e2gqd6ZukQnGtLyKUXW7rXRvdFddiKA6" width="60%">
# </p>

# %% [markdown]
# This is much better 🙌
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1z-wxG7QV8pqwEIt7vnocHoee9XsITAXM" width="60%">
# </p>

# %% [markdown]
# ---

# %% [markdown]
# # III. The toolbox 🧰

# %% [markdown]
# We now have a good understanding of why data visualization is important, and how we can build great dataviz (on paper for now).
#
# Let's have a quick tour of the tools we can use, and their specificities.

# %% [markdown]
# ## III.1. Python libraries

# %% [markdown]
# ### III.1.A. Matplotlib

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1Qk0dg38WS4y4xxlaCR0S6KtzWknRiXNt" width="400">
# </p>
#
# `matplotlib` is the **main data visualization library of Python**. It allows you to create charts with a lot of parameters options.
#
# You can search online for what you want to create beforehand if needed:
# - https://matplotlib.org/
# - https://python-graph-gallery.com
# - https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python

# %%
# First, from the `matplotlib` library, we import the module `pyplot` with the alias `plt`
# (importing the entire library is not necessary)
import matplotlib.pyplot as plt

# %% [markdown]
# Let's explore the principal charts with `matplotlib`. We'll start by exploring the anatomy of a **figure** and how to create one in `matplotlib`.

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1rhajOgWmGNIfYy8FgNLWoz83Sgj-b1iL" width="600">
# </p>

# %% [markdown]
# #### Decorating your plot
#
# You can then detail properly:
# - the title of the figure: `plt.title('Chart Title')`
# - the axis label: with `plt.xlabel("X-title")` and `plt.ylabel("Y-title")`
#
# As you will see in the documentation, matplotlib offers a variety of parameters in these functions to custom your charts as you wish.
#
# After all that, you call the function `plt.show()` in order to draw the figure.

# %%
# Creating the figure
plt.figure()

# We can add axis labels
plt.xlabel('X-axis (in units)', fontsize='14')
plt.ylabel('Y-axis (in units)', fontsize='14')

# We can add and format a title for our chart
plt.title('My wonderful chart', 
          fontweight='bold', color='black', fontsize='16', alpha=0.8)

# At the end, we display the plot with `plt.show()`
plt.show()

# It only displays the axis here because we did not specify a plot to draw nor values to take

# %% [markdown]
# #### `plt.figure`
#
# When creating a chart with `pyplot`, it creates automatically a figure (container for your charts).
#
# But you can create it yourself in order to, for example, specify the size of your figure with `figsize=(width, height)` with dimensions in inches.

# %%
# Same chart as before, but first we create a figure (container for your charts)
# with an appropriate size
plt.figure(figsize=(12,6))

# We can add axis labels
plt.xlabel('X-axis (in units)', fontsize='14')
plt.ylabel('Y-axis (in units)', fontsize='14')

# We can add and format a title for our chart
plt.title('My wonderful chart', 
          fontweight='bold', color = 'black', fontsize='16', alpha=0.8)

# At the end, we display the plot with `plt.show()`
plt.show()

# %% [markdown]
# #### `plt.hist`
#
# You can easily draw histograms with `pyplot` using the `plt.hist` function.
#
# This allows you to visualize the **distribution** of your data into different **bins** (or bars or buckets) of the same size.
#
# Bins represents identical range of values, the height of the bar corresponds to the number of values contained in this range.

# %%
# Distribution > Histogram (column or line)
import numpy as np
mu = 200
sigma = 25
x = np.random.normal(mu, sigma, size=1000)

plt.figure(figsize=(10,5))

# Here we specify that we want 20 bins for our histogram
plt.hist(x, bins=20, facecolor='blue', alpha=0.5)

plt.title('Histogram of Normal Distribution (random draw)', fontweight='bold')
plt.show()

# %% [markdown]
# #### `plt.scatter`
#
# You can visualize data points on a X vs Y axis by using `plt.scatter`
#
# It is very useful when looking for **correlations** between 2 variables for example.
#
# This function draws a scatter plot of the observations. It displays values for typically two variables for a set of data. You can also display more variables by coloring the points, or varying the size.

# %%
# Relationship > 2D > Scatter chart
x = range(1,101)
y = x + np.random.randn(100) * 15

plt.figure(figsize=(10,5))

plt.scatter(x=x, 
            y=y, 
            marker='o',
            alpha=0.5)

plt.show()

# %%
# Relationship > 3D > Bubble chart
# It is a scatter plot with varying size (variable `s`) of the points
x = np.random.rand(100) - 0.5
y = x + np.random.rand(100)
z = x + x * np.random.rand(100)

plt.figure(figsize=(10,5))

plt.scatter(x, y, s=z * 1000, alpha=0.5)

plt.show()
# Out:
# /anaconda3/envs/vivaenv/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
# Relationship > 3D > Scatter colored chart (discrete or continue variables)
# It is a scatter plot with varying color (variable `c`) depending on the points

# Loading iris dataset - we will talk about it later
import seaborn as sns    # seaborn is another very useful data visualization library
import pandas as pd
df = sns.load_dataset('iris')
df['species'] = pd.Categorical(df['species'])

# Constructing the figure
plt.figure(figsize=(10,5))

plt.scatter(x=df['sepal_length'],
            y=df['sepal_width'],
            c=df['species'].cat.codes,
            cmap="Set1", # `cmap` is the colormap (or palette), try "rainbow" for example
                         # List of plt colormaps and how to choose it:
                         # https://matplotlib.org/examples/color/colormaps_reference.html
            alpha=0.8)   # alpha is transparency parameter

plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width') 
plt.show()

# %% [markdown]
# #### `plt.plot`
#
# One of the most classical chart: `plt.plot`.
#
# Draws lines between the data points. Especially useful with time series.

# %%
# Evolution > Many data points (ex: Time series) > Line chart

plt.figure(figsize=(10,5))

x = range(1900, 2000)
y = range(100) + np.random.randn(100) * 15

plt.plot(x, y,
         marker='x', # Markers used for your data points - try 'o'
         linestyle='--', # Style used for your lines - try '-'
         color='mediumvioletred',
         alpha=0.5)

plt.title("Evolution of xxx during 21th century")
plt.show()

# %% [markdown]
# #### `plt.bar`
#
# You can build a **column chart** with `plt.bar`.
#
# It is mostly used to compare data with a few items of few categories.

# %%
# Evolution > Few data points > Column chart
plt.figure(figsize=(10, 5))

bars = ['Q1 2018', 'Q2 2018', 'Q3 2018', 'Q4 2018']
sales = [12, 14, 25, 59]

plt.bar(x=bars,
        height=sales)

plt.ylabel("Sales (in M€)")
plt.title("Sales have skyrocketed Month-Over-Month (MoM)!", 
          fontweight='bold', fontsize='14', alpha=0.8)
plt.show()

# %% [markdown]
# #### `plt.stackplot`
#
# If you want to observe the composition of some data and its **relative** evolution over time, you can use the `plt.stackplot` function.
#
# This will plot and color the evolution of your groups share (max 100%).

# %%
# Evolution Share Of Voice (SoV) > Stacked 100% column chart

# Creating the data
data = pd.DataFrame({'group_A':[1,4,6,8,9],
                     'group_B':[2,24,7,10,12],
                     'group_C':[2,8,5,10,6], },
                     index=range(1,6)
                   )
# We need to transform the data from raw data to percentage (fraction)
data_perc = data.divide(data.sum(axis=1), axis=0)

# Creating the figure
plt.figure(figsize=(10, 5))

# Make the plot
plt.stackplot(range(1,6),
              data_perc["group_A"], 
              data_perc["group_B"], 
              data_perc["group_C"],
              labels=['A','B','C'])

# Formatting the plot
plt.legend(loc='upper left')
plt.margins(0,0)
plt.title('Evolution of market share over time')
plt.show()

# %% [markdown]
# #### `plt.subplot` - digging deeper
#
# Now let's demo briefly how to showcase multiple charts at the same time with `plt.subplot`
#
# It works likes this: `plt.subplot(nrows, ncolumns, index)`
#
#
# <p align="center">
# <img src="data:image/png;base64,..." />
# </p>
#
# You can use `plt.tight_layout()` to automatically arrange your plots (and prevent overalapping for example)

# %%
# Loading data
x = range(1,101)
y = np.random.randn(100) * 15 + range(1,101)
z = (np.random.randn(100) * 15 + range(1,101)) * 2

# %%
# Display charts in two columns
 
plt.figure(figsize=(12,5))

plt.subplot(1, 2, 1)
plt.plot( x, y, marker='o', alpha=0.4)

plt.subplot(1, 2, 2)
plt.plot(x, y, linestyle='none', marker='o', color="orange", alpha=0.5)

plt.tight_layout()
plt.show()

# %%
# Display charts in two rows - Note that we can get rid of the "," in the subplot function
 
plt.figure(figsize=(10, 8))

plt.subplot(211)
plt.plot(x, y, marker='o', alpha=0.4)
 
plt.subplot(212)
plt.plot(x, y, linestyle='none', marker='o', color="orange", alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# You can even do more advanced stuff with `plt.subplot2grid`. For example:
#
# ``` python
# ax1 = plt.subplot2grid((3, 3), (0, 0), colspan=3)
# ax2 = plt.subplot2grid((3, 3), (1, 0), colspan=2)
# ax3 = plt.subplot2grid((3, 3), (1, 2), rowspan=2)
# ax4 = plt.subplot2grid((3, 3), (2, 0))
# ax5 = plt.subplot2grid((3, 3), (2, 1))
# ```
#
# <p align="center">
# <img src="https://matplotlib.org/_images/demo_gridspec01.png">
# </p>

# %%
# More advanced/custom charts arrangement with `plt.subplot2grid`
# Example: grid of 4 columns and 2 rows
 
plt.figure(figsize=(12,10))

# The first plot is on line 1, and is spread all along the 4 columns
ax1 = plt.subplot2grid((2, 4), (0, 0), colspan=4)
ax1.plot(x, y , marker='o', alpha=0.5)

# The second one is on column2, spread on 3 columns
ax2 = plt.subplot2grid((2, 4), (1, 0), colspan=3)
ax2.plot(x, y, marker='o', color="grey", alpha=0.5)

# The last one is spread on 1 column only, on the 4th column of the second line.
ax3 = plt.subplot2grid((2, 4), (1, 3), colspan=1)
ax3.plot(x, z, marker='o', color="orange", alpha=0.5)

plt.show()

# %% [markdown]
# ### III.1.B. Seaborn

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1OEQBDTHGNsV_UoYHQubWM0FPRLGrsGE3" width="200">
# </p>
#
#
# `seaborn` is a Python library built on top of Matplotlib that provides:
# - utility functions to easily plot useful statistical representations and visualisations
# - control styling on matplotlib charts and built-in color themes
#
# In other words, **it is `matplotlib`, just simpler and more powerful**.
#
# > 🔦 **Hints**:
# - For example, unlike matplotlib (which expects Numpy arrays or list), *sometimes* data can be fed to seaborn as a DataFrame - which is extremely convenient
# - We can still use matplotlib functions for formatting/displaying charts

# %% [markdown]
# #### Boxplot - To show distributions with respect to categories.
#
# A **box plot** (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable.
#
# The box plot allows quick graphical examination your data:
# - Box and whisker shows **[quartiles](https://en.wikipedia.org/wiki/Quartile)**
# - The band inside the box is the **second quartile (the median)**
# - The ends of the whiskers represents **minimum and maximum of all data** (most of the time - sometimes ends of the whisker can represent other values)
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=12BKqzNh8qsAVu3f7vZ-DQIyAUo7fu_5p" width="400">
# </p>
#
# > 📚 **Resources** : For a complete understanding of the boxplot chart, read [Wikipedia - Box Plot](https://en.wikipedia.org/wiki/Box_plot)

# %%
import seaborn as sns

# %%
# Example: `sns.boxplot` for distribution

plt.figure(figsize=(12, 6))

# Seaborn also has utility functions to load ready-to-play datasets
# This one concerns different tips in restaurants 💸
df = sns.load_dataset("tips")

sns.boxplot(x="tip", data=df)

plt.title('Boxplot of tip variable')
plt.show()

# %% [markdown]
# #### Violinplot
#
# A **violin plot** is more informative than a box plot :
# - a box plot only shows summary statistics such as mean/median and interquartile ranges ;
# - a violin plot shows **the full distribution of the data**.
#
# ➡️ The difference is particularly useful when the data distribution is multimodal (more than one peak). In this case a violin plot shows the presence of different peaks, their position and relative amplitude.
#
# > 📚 **Resources** : For a complete understanding of the violinplot chart, read [Wikipedia - Violin Plot](https://en.wikipedia.org/wiki/Violin_plot)

# %%
# Example : `sns.violinplot` for distribution

plt.figure(figsize=(12, 6))

# Seaborn also has utility functions to load ready-to-play datasets
# This one concerns different tips in restaurants 💸
df = sns.load_dataset("tips")

sns.violinplot(x="tip", data=df)

plt.title('Violin plot of tip variable')
plt.show()

# %%
# `sns.violinplot` allows you to easily compare distributions

plt.figure(figsize=(12, 6))

sns.violinplot(x="time", y='tip', hue='sex', data=df, split=True)

plt.title('Violin plot of tip variable, depending on the time and the sex')
plt.show()

# %% [markdown]
# #### Histogram plot - To show univariate distribution of observations
#
# The seaborn function `sns.distplot` combines the matplotlib `hist` function (with automatic calculation of a good default bin size) with the seaborn `kdeplot()` (that plots a smooth density estimation).

# %%
# Example: `sns.displot` for distribution

plt.figure(figsize=(12, 6))

# Seaborn also has utility functions to load ready-to-play datasets
# This one concerns different types of flowers 🌺
df = sns.load_dataset("iris")

sns.distplot(df["sepal_length"])

plt.title('Distribution of Sepal Length')
plt.show()

# %% [markdown]
# #### Scatter plot - To plot a collection of data points
#
# `sns.scatterplot` function draws a scatter plot of the observations. It displays values for typically two variables for a set of data. You can also display more variables by coloring the points, or varying the size.

# %%
# Example: `sns.scatterplot` - for plotting data points

plt.figure(figsize=(12, 6))

sns.scatterplot(x="sepal_length", y="sepal_width", data=df, hue="species")

plt.show()

# %% [markdown]
# #### Pair plot - a magic function 🎩
#
# `sns.pairplot` is quite magical, you call it on your dataset and it draws **pairwise relationships in a dataset**. This means:
# - each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column - `scatter_plot`
# - The diagonal Axes are treated differently, drawing a plot to show the univariate distribution of the data for the variable in that column - `kde_plot`

# %%
# Example: `sns.pairplot` - a magic function

# We specify another style to our seaborn viz
sns.set(style="ticks")

# Magic `pairplot` function
sns.pairplot(df, hue="species")

plt.show()

# %% [markdown]
# #### Adding one more dimention to your plot with sns.relplot and sns.catplot

# %% [markdown]
# ##### Relplot - To plot relations between continuous variables
#
# Another useful seaborn function: `sns.relplot` for plotting 2 faces relational plots sharing the same X-Y axis and legend but with a varying column defined in `col`.
#
# You can plot either :
# - **Scatterplots**, by specifying the parameter `kind="scatter"`
# - **Lineplots**, by specifying the parameter `kind="line"`.

# %%
# Another example: `sns.relplot` - facing scatter plots

# Optional: we apply the default seaborn theme, scaling, and color palette
sns.set()

# Seaborn also has utility functions to load ready-to-play datasets
# This one concerns tips in restaurant 💸
df = sns.load_dataset("tips")

plt.figure()

sns.relplot(x="total_bill", y="tip", hue="sex", col='time', data=df, kind="scatter")

plt.show()

# %% [markdown]
# ##### Catplot - To plot comparisons between categorical variables
#
# `sns.catplot` is used for plotting 2 faces categorical plots sharing the same X-Y axis and legend but with a varying column defined in `col`.
#
# You can plot :
# - **Boxplots**, by specifying the parameter `kind="box"`
# - **Violinplots**, by specifying the parameter `kind="violin"`.
# - **Barplots**, by specifying the parameter `kind="bar"`
# - **Countplots**, by specifying the parameter `kind="count"`.
# - And many others : refer to the [documentation](https://seaborn.pydata.org/generated/seaborn.catplot.html) for more details.

# %%
# Another example: `sns.catplot` - facing box plots
plt.figure()

sns.catplot(x="sex", y="tip", hue="smoker", col='time', data=df, kind="box")

plt.show()

# %% [markdown]
# ### III.1.C. Bokeh

# %% [markdown]
# [`bokeh`](https://bokeh.pydata.org/en/latest/) is another Python visualization library with some interactivity features.
#
# For example: [Iris visualization](https://bokeh.pydata.org/en/latest/docs/gallery/iris.html) 🌺

# %%
# Code is quite not so different from what we have seen before.
from bokeh.plotting import figure, show, output_file
from bokeh.sampledata.iris import flowers

colormap = {'setosa': 'red', 'versicolor': 'green', 'virginica': 'blue'}
colors = [colormap[x] for x in flowers['species']]

p = figure(title = "Iris Morphology")
p.xaxis.axis_label = 'Petal Length'
p.yaxis.axis_label = 'Petal Width'

p.circle(flowers["petal_length"], flowers["petal_width"],
         color=colors, fill_alpha=0.2, size=10)

show(p)

# %% [markdown]
# ## III.2. Dataviz softwares

# %% [markdown]
# Data visualization does not have to be so painful.
#
# Building charts with Python is very powerful but if you do that all day long, maybe the best is to use dedicated softwares that make dataviz easy.
#
# We will mention the most popular: **Tableau**, **Dataiku** and **Excel**

# %% [markdown]
# ### III.2.A. Tableau

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1HMi6SasrQ3ecyr1jJxEfegLVQTix6rVi" width="400">
# </p>

# %% [markdown]
# Tableau is **one of the most powerful** - yet easy to use- **data visualization software** 💪
#
# It contains a lot of "built-in connectors" for connecting/importing your data, and the interface is quite intuitive and straightforward:
# - You **select your chart type**
# - You **select your variables** for X-axis, Y-axis, and more (maybe a variable for the color of the data point? maybe a variable for varying size? etc.)
# - You **polish your visualization** (maybe you want to add a trend line? or an horizontal line representing the mean value? Or highlight some of your data points? Or combine different charts into one view? etc.)
# - You **deploy it online** and make it accessible to everyone (or only everyone working at your company).
#
# The only drawback is that it can be pricy.
#
# Check the gallery for a few examples: https://public.tableau.com/en-us/s/gallery
#
# ---
#
# <img src="https://drive.google.com/uc?export=view&id=1x2siaeMf8yfG6NfUVHhvfDPot49Id1ND">

# %% [markdown]
# ### III.2.B. Dataiku 🇫🇷

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1POoKGayZ39oJbTcrY_DLE97t2eG0v83f" width="200">
# </p>

# %% [markdown]
# Also a **very powerful sofware** that **offers intuitive UI**.
#
# But in Dataiku, you can do much more than just data visualization: you can **apply pipelines** (or recipes) to your data and **automate your analysis**.
#
# Example of Dataiku pipeline:
# 1. Loading different datasets
# - Merging/joining them
# - Cleaning them
# - Applying a machine learning classification algorithm
# - Saving results in a new dataset
# - etc.
#
# That makes it a great toolbox for people working with data and looking for an intuitive interface to apply classical data operations (for cleaning/exploring/visualizing & analyzing).
#
# #### Data science pipelines with Dataiku
#
# <img src="https://drive.google.com/uc?export=view&id=1u-wbTAwiGFTzwdKKqHiwlLLWDU0qTO0l" >
#
# ---
#
# #### Data visualization with Dataiku
#
# <img src="https://drive.google.com/uc?export=view&id=1bOllMIb0vXhtQEA8Pso0bMjGmhZ7St6B">

# %% [markdown]
# ### III.2.C. Excel

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1XqvYgIQVcGpvb_xr-P1pVNUIs8dvs6ZB" width="100">
# </p>
#
# Sometimes, all you need is a **simple pivot table**! 😏

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1VykQNGQ7KKWJX6iEaIKH-Athw4-RhIMV" >
# </p>

# %% [markdown]
# ## Data Exploration 🔬

# %% [markdown]
# ---

# %% [markdown]
# Data Science is all about exploring and analyzing data. In this lecture, we will learn a simple process for a in-depth exploration and analysis of your data. This is called **Exploratory Data Analysis**, and it is required at the beginning of any data science project.
#
# <img src="https://drive.google.com/uc?export=view&id=1psmZPOSuqy1V8eHNCdHjhuzF0pWtXS04" >

# %% [markdown]
# We will explain the process of EDA through a famous and intuitive example: the **Titanic disaster**.
#
# Let's start right away!
#
# <p align="center">
# <img src="https://www.slate.fr/sites/default/files/styles/1060x523/public/000_arp1718951.jpg" width="600px">
# </p>

# %% [markdown]
# ---

# %% [markdown]
# # I. Descriptive analysis

# %% [markdown]
# ## I.1. Loading the data

# %% [markdown]
# First, we load the data. As explained before, we will use Pandas and the DataFrame object.

# %%
import os
data_path = os.path.join("..","..","..","..","data", "titanic.csv")

# %%
import pandas as pd

data = pd.read_csv(data_path)

# %% [markdown]
# We can check the dataset has properly loaded. In order not to display all lines, we will only display the first lines with the `head` method (you can also check last by using `tail`).

# %%
data.head(n=4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %% [markdown]
# ## I.2. Global overview of the data

# %% [markdown]
# It's always interesting to start by a brief overview of the data.
#
# Which means:
# - to check the `shape` of the data (to understand the size of our dataset)
# - to get a brief summary with the `describe` and `info` methods
# - to draw a global visualization of the data and relationships between variables using `sns.pairplot`

# %% [markdown]
# **`.shape`**: returns the shape of the dataframe as a tuple in the format (rows, columns)
#
# > 🔦 Hint: `shape` is an attribute and not a method so no need to use parentheses.

# %%
data.shape
print("data.shape={}".format(data.shape))
print("Our dataset contains {} rows and {} columns".format(data.shape[0], data.shape[1]))
# Out:
# data.shape=(891, 12)
# Our dataset contains 891 rows and 12 columns

# %% [markdown]
# **`.info()`**: Print a concise summary of a DataFrame (index dtype, column dtypes, non-null values and memory usage)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# **`.describe()`**: Generates descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution. It excludes NaN values.
#
#
# > 🏆 **Quizz**: To which values do you think **25%**, **50%** and **75%** corresponds to?

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# The method `describe()` does not describe **categorical values** per default. We can describe them too by specifying `include=['object']`.

# %%
data.describe(include=['object'])
# Out:
#                     Name   Sex  Ticket    Cabin Embarked
# count                891   891     891      204      889
# unique               891     2     681      147        3
# top     Bourke, Mr. John  male  347082  B96 B98        S
# freq                   1   577       7        4      644

# %% [markdown]
# **`sns.pairplot`**: can be also quite useful for understanding the distribution of your data, and some potential correlations

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure()

sns.pairplot(data)

plt.show()

# %% [markdown]
# Let's list a **few of the insights** we started gathering:
#
# - Our dataset consists of  **891 lines corresponding to 891 passengers** - with several associated characteristics (Age, Name, Sex, Ticket Fare, etc.) and **a binary variable Survived** detailing if the passenger survived (categorical value: 0 or 1).
#
# - The dataset contains a **40% sample of the total Titanic population** (as the boat transported 2224 passengers)
#
# - For this sample, the **survival rate is about 38%**.
#
# - Ticket prices varied **significantly from a few dollars to 512$**.

# %% [markdown]
# # II. Data cleaning

# %% [markdown]
# Before going further into the analysis, we need to check potential issues such as:
# - missing or N/A values
# - duplicated lines
# - data not properly loaded
# - etc.
#
# and clean them.

# %% [markdown]
# ### II.1. Handle Missing values

# %% [markdown]
# We can check missing values using `data.isnull().sum()`
#
# - `data.isnull()` returns the DataFrame with all values replaced by a **boolean** indicating if the value is N/A
# - we just have to apply `sum` method to the column axis of this DataFrame (as by default, the sum of an empty or NA value counts as 0)

# %%
# Find missing data
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# We can solve those issues differently:
# - A lot of missing values in Cabin column, the column does not appear useful: we will **drop the column**
# - Only 2 in Embarked column, we will **drop the 2 rows**
# - 177 in Age which should be an important feature, we will **replace empty values with the `mean()` of the existing values**

# %%
# Cleaning Cabin - removing column
data_cleaned = data.drop(['Cabin'], axis=1)

# Cleaning Embarked - removing rows with missing values
data_cleaned = data_cleaned.dropna(subset=["Embarked"])

# Cleaning Age - replacing by mean value
data_cleaned["Age"] = data["Age"].fillna(data["Age"].mean())

# %% [markdown]
# ### II.2. Remove Duplicated lines

# %% [markdown]
# Is there any duplicated lines? We can check using `duplicated()` method.

# %%
# Find duplicated lines
data.duplicated().sum() # Returns 0 => there are no duplicated lines in the dataset

# %% [markdown]
# ---

# %% [markdown]
# # III. Univariate analysis

# %% [markdown]
# Let's go deeper in our analysis. Especially let's try to understand **how passengers' characteristics impact their propability of survival**.
#
# > **Remember that the quality of your analysis will depend on the questions you choose to answer.**
#
# When performing data analysis, we start by exploring one variable and its distribution (univariate analysis), and then we can add up other variables and perform multivariate analysis.

# %% [markdown]
# ## III.1. Gender

# %% [markdown]
# First, let's visualize the **number of passengers per gender** (univariate analysis).

# %%
plt.figure(figsize=(6, 5))

# Plot the number of passengers per gender
sns.countplot(x='Sex',
              order=["female", "male"], 
              data=data_cleaned,
              palette="Blues")

# Write the labels on top
grouped_values = data_cleaned.groupby("Sex").Sex.count()
for label, value in enumerate(grouped_values):
    plt.text(label, value - 50, round(value,2), color='black', ha="center")

plt.title('Number of passengers per gender')
plt.show()

# %% [markdown]
# Now, let's visualize the **survival rate per gender**

# %%
plt.figure(figsize=(6, 5))

# Plot the Survival Rate per Sex
sns.barplot(x='Sex',
            y='Survived',
            order=["female", "male"],
            data=data_cleaned,
            ci=None, # Removing confidence intervals
            palette="Blues")

# Write the labels on top
grouped_values = data_cleaned.groupby("Sex").Survived.mean()
for idx, value in enumerate(grouped_values):
    plt.text(idx, value - 0.1, round(value,2), color='black', ha="center")
    
plt.title('Survival rate per Gender')
plt.show()

# %% [markdown]
# We observe a **drastic difference in survival rate**! **74% of women survived, vs 19% of men**...
#
# It appears that women were more likely to survive, but it might be too soon to conclude anything. Maybe another variable is the root cause behind these discrepancies.
#
# Let's now analyse the variable Age and its relationship with the survival rate.

# %% [markdown]
# ## III.2. Age

# %% [markdown]
# Again, let's start by visualizing the **distribution of our data** (univariate analysis).
#
# > 🔦 **Hint**: We are visualizing `data` and not `data_cleaned` as we would have a peak at 30 - the mean value we used to replace NaN values

# %%
plt.figure(figsize=(8,6))
sns.distplot(data.loc[data['Age'].notnull(), 'Age'])
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# Does this distribution change depending on the Gender?

# %%
plt.figure(figsize=(8,6))

sns.distplot(data.loc[data['Age'].notnull() & (data['Sex'] == 'male'), 'Age'],
             label='male')
sns.distplot(data.loc[data['Age'].notnull() & (data['Sex'] == 'female'), 'Age'],
             label='female')
plt.title('Age Distribution by Gender')
plt.legend()
plt.show()

# %% [markdown]
# Now let's explore the Survival rate depending on the Age.

# %%
plt.figure(figsize=(8,6))

sns.distplot(data.loc[data['Age'].notnull() & (data['Survived'] == 1), 'Age'],
             label='Survived')
sns.distplot(data.loc[data['Age'].notnull() & (data['Survived'] == 0), 'Age'],
             label='Perished')
plt.title('Age Distribution by Survived')
plt.legend()
plt.show()

# %% [markdown]
# Not very "readable". We observe a peak of survivals around < 5 years old, but not sure how to interpret it.
#
# Sounds more interesting to visualize survival rate depending on Age.
#
# Let's think about a clever way on how to do that.

# %%
def get_age_group(x):
    idx_group = int(x // 10)
    name_group = "{} to {}".format(idx_group*10, (idx_group+1)*10)
    return name_group

data_cleaned["Age_group"] = data_cleaned["Age"].apply(get_age_group)

sr_by_age_group = data_cleaned.groupby("Age_group")["Survived"].mean()
print(sr_by_age_group)
# Out:
# Age_group
# 0 to 10     0.612903
# 10 to 20    0.401961
# 20 to 30    0.324937
# 30 to 40    0.433735
# 40 to 50    0.382022
# 50 to 60    0.416667
# 60 to 70    0.277778
# 70 to 80    0.000000
# 80 to 90    1.000000
# Name: Survived, dtype: float64

# %%
plt.figure(figsize=(12, 8))

sns.barplot(x="Age_group", y="Survived", palette ="Blues", ci=None,
            order=sr_by_age_group.index[:-2],
            data=data_cleaned.loc[data_cleaned.Age < 70])
plt.show()

# %% [markdown]
# We can extend this analysis and break it per gender using `hue`

# %%
plt.figure(figsize=(12, 8))

sns.barplot(x="Age_group", y="Survived", palette ="Blues", ci=None,
            hue="Sex",
            order=sr_by_age_group.index[:-2],
            data=data_cleaned.loc[data_cleaned.Age < 70])
plt.show()

# %% [markdown]
# Sounds safe to conclude: **Women and children first!** 🚢
#
# > 📚 **Resources** : if you want to dig deeper, [this article](https://medium.com/better-programming/healthcare-fraud-detection-with-python-5a7a6738b5b2) is a good breakdown of the uses and techniques of exploratory data analysis.
#
# <p align="center">
# <img src="https://cache.marieclaire.fr/data/photo/w1000_c17/4s/titanic.jpg" width="400px" />
# </p>
